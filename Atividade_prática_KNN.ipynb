# %%
# Training data with 2 features and without normalization
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

total_sulfur_dioxide = []
citric_acid = []
classes = []

total_sulfur_dioxide_test = []
citric_acid_test = []
classes_test = []

with open('Dados_Originais_2Features/TrainingData_2F_Original.txt', 'r') as training_file:
    next(training_file)
    for line in training_file:
        values = line.split('\t')
        total_sulfur_dioxide.append(float(values[1]))
        citric_acid.append(float(values[2]))
        classes.append(int(values[3]))

with open('Dados_Originais_2Features/TestingData_2F_Original.txt', 'r') as test_file:
    next(test_file)
    for line in test_file:
        values = line.split('\t')
        total_sulfur_dioxide_test.append(float(values[1]))
        citric_acid_test.append(float(values[2]))
        classes_test.append(int(values[3]))

data = list(zip(total_sulfur_dioxide, citric_acid))
test_data = list(zip(total_sulfur_dioxide_test, citric_acid_test))

knn = KNeighborsClassifier(n_neighbors=5, p=2, metric='minkowski', n_jobs=-1)

knn.fit(data, classes)

plt.scatter(total_sulfur_dioxide + total_sulfur_dioxide_test, citric_acid + citric_acid_test, c=classes + classes_test)
plt.show()

test_pred = knn.predict(test_data)

accuracy = accuracy_score(classes_test, test_pred)

print(accuracy)
# Out:
# 0.25

# %%
# Training data with 2 features and with normalization
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

total_sulfur_dioxide = []
citric_acid = []
classes = []

total_sulfur_dioxide_test = []
citric_acid_test = []
classes_test = []

with open('Dados_Normalizados_2Features/TrainingData_2F_Norm.txt', 'r') as training_file:
    next(training_file)
    for line in training_file:
        values = line.split('\t')
        total_sulfur_dioxide.append(float(values[1]))
        citric_acid.append(float(values[2]))
        classes.append(int(values[3]))

with open('Dados_Normalizados_2Features/TestingData_2F_Norm.txt', 'r') as test_file:
    next(test_file)
    for line in test_file:
        values = line.split('\t')
        total_sulfur_dioxide_test.append(float(values[1]))
        citric_acid_test.append(float(values[2]))
        classes_test.append(int(values[3]))

data = list(zip(total_sulfur_dioxide, citric_acid))
test_data = list(zip(total_sulfur_dioxide_test, citric_acid_test))

knn = KNeighborsClassifier(n_neighbors=1, p=2, metric='minkowski', n_jobs=-1)

knn.fit(data, classes)

plt.scatter(total_sulfur_dioxide, citric_acid, c=classes)
plt.show()

test_pred = knn.predict(test_data)

accuracy = accuracy_score(classes_test, test_pred)

print(accuracy)
# Out:
# 0.5

# %%
# Training data with 11 features and without normalization
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

data = []
classes = []
test_data = []
test_classes = []

with open('Dados_Originais_11Features/TrainingData_11F_Original.txt', 'r') as training_file:
    next(training_file)
    for line in training_file:
        values = line.split('\t')
        features_value = []
        for num in values[1:12]:
            features_value.append(float(num))
        classes.append(int(values[12]))
        data.append(features_value)


with open('Dados_Originais_11Features/TestingData_11F_Original.txt', 'r') as test_file:
    next(test_file)
    for line in test_file:
        values = line.split('\t')
        features_value = []
        for num in values[1:12]:
            features_value.append(float(num))
        test_classes.append(int(values[12]))
        test_data.append(features_value)

knn = KNeighborsClassifier(n_neighbors=7, p=2, metric='minkowski', n_jobs=-1)
knn.fit(data, classes)

test_pred = knn.predict(test_data)

accuracy = accuracy_score(test_classes, test_pred)

print(accuracy)
# Out:
# 0.5

# %%
# Training data with 11 features and with normalization
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

data = []
classes = []
test_data = []
test_classes = []

with open('Dados_Normalizados_11Features/TrainingData_11F_Norm.txt', 'r') as training_file:
    next(training_file)
    for line in training_file:
        values = line.split('\t')
        features_value = []
        for num in values[1:12]:
            features_value.append(float(num))
        classes.append(int(values[12]))
        data.append(features_value)


with open('Dados_Normalizados_11Features/TestingData_11F_Norm.txt', 'r') as test_file:
    next(test_file)
    for line in test_file:
        values = line.split('\t')
        features_value = []
        for num in values[1:12]:
            features_value.append(float(num))
        test_classes.append(int(values[12]))
        test_data.append(features_value)

knn = KNeighborsClassifier(n_neighbors=7, p=2, metric='minkowski', n_jobs=-1)
knn.fit(data, classes)

test_pred = knn.predict(test_data)

accuracy = accuracy_score(test_classes, test_pred)

print(accuracy)
# Out:
# 0.75

# %%
# Test N4 with 2 and 11 normalized features
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

data = []
classes = []
test_data = []
test_classes = []

with open('Dados_Normalizados_2Features/TrainingData_2F_Norm.txt', 'r') as training_file:
    next(training_file)
    for line in training_file:
        values = line.split('\t')
        features_value = []
        for num in values[1:3]:
            features_value.append(float(num))
        classes.append(int(values[3]))
        data.append(features_value)


with open('Dados_Normalizados_2Features/TestingData_2F_Norm.txt', 'r') as test_file:
    for num in range(1,5):
        next(test_file)
    n4 = next(test_file).split('\t')
    features_value = []
    for num in n4[1:3]:
        features_value.append(float(num))
    test_classes.append(int(n4[3]))
    test_data.append(features_value)

knn = KNeighborsClassifier(n_neighbors=5, p=2, metric='minkowski', n_jobs=-1)
knn.fit(data, classes)

test_pred = knn.predict(test_data)

print(test_pred)
# Out:
# [0]
